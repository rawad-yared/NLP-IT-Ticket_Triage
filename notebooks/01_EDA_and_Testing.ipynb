# %% [markdown]
# # IT Ticket Triage NLP Project - Phase 0: Colab Setup

# %% [markdown]
# This notebook initializes a reproducible Colab environment for dataset loading, model training, and output tracking.

# %%
# Phase 0 starter cell: requirements, Drive mount, seeds, and config will be added next.
